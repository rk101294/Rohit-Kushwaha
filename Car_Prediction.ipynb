# %% [markdown]
# <a href="https://colab.research.google.com/github/rk101294/Rohit-Kushwaha/blob/master/Car_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Importing All Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #**Reading Data**

# %%
data= pd.read_csv("car data.csv")

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]

# %% [markdown]
# **Copy into different variable**

# %%
msg=data.copy()

# %%
msg.head()
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]

# %%
msg.drop(axis=1,columns="Car_Name",inplace=True)

# %%
msg.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Seller_Type Transmission Owner
# 0  2014           3.35           5.59  ...       Dealer       Manual     0
# 1  2013           4.75           9.54  ...       Dealer       Manual     0
# 2  2017           7.25           9.85  ...       Dealer       Manual     0
# 3  2011           2.85           4.15  ...       Dealer       Manual     0
# 4  2014           4.60           6.87  ...       Dealer       Manual     0
#
# [5 rows x 8 columns]

# %%
msg.isnull().sum()
# Out:
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
msg["Current_Year"]=2020

# %%
msg.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Transmission Owner Current_Year
# 0  2014           3.35           5.59  ...        Manual     0         2020
# 1  2013           4.75           9.54  ...        Manual     0         2020
# 2  2017           7.25           9.85  ...        Manual     0         2020
# 3  2011           2.85           4.15  ...        Manual     0         2020
# 4  2014           4.60           6.87  ...        Manual     0         2020
#
# [5 rows x 9 columns]

# %%
msg.describe()
# Out:
#               Year  Selling_Price  ...       Owner  Current_Year
# count   301.000000     301.000000  ...  301.000000         301.0
# mean   2013.627907       4.661296  ...    0.043189        2020.0
# std       2.891554       5.082812  ...    0.247915           0.0
# min    2003.000000       0.100000  ...    0.000000        2020.0
# 25%    2012.000000       0.900000  ...    0.000000        2020.0
# 50%    2014.000000       3.600000  ...    0.000000        2020.0
# 75%    2016.000000       6.000000  ...    0.000000        2020.0
# max    2018.000000      35.000000  ...    3.000000        2020.0
#
# [8 rows x 6 columns]

# %%
msg["Total_Year"]=msg["Current_Year"]-msg["Year"]

# %%
msg.head()
# Out:
#    Year  Selling_Price  Present_Price  ...  Owner Current_Year Total_Year
# 0  2014           3.35           5.59  ...      0         2020          6
# 1  2013           4.75           9.54  ...      0         2020          7
# 2  2017           7.25           9.85  ...      0         2020          3
# 3  2011           2.85           4.15  ...      0         2020          9
# 4  2014           4.60           6.87  ...      0         2020          6
#
# [5 rows x 10 columns]

# %%
msg.drop(axis=1,columns="Year",inplace=True)
msg.drop(axis=1,columns="Current_Year",inplace=True)

# %%
msg.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  ... Transmission Owner Total_Year
# 0           3.35           5.59       27000  ...       Manual     0          6
# 1           4.75           9.54       43000  ...       Manual     0          7
# 2           7.25           9.85        6900  ...       Manual     0          3
# 3           2.85           4.15        5200  ...       Manual     0          9
# 4           4.60           6.87       42450  ...       Manual     0          6
#
# [5 rows x 8 columns]

# %%
print(msg["Fuel_Type"].unique())
print(msg["Seller_Type"].unique())
print(msg["Transmission"].unique())
print(msg["Owner"].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %% [markdown]
# # **One Hot Encoding**

# %%
msg=pd.get_dummies(msg,drop_first=True)

# %%
msg.head()
# Out:
#    Selling_Price  Present_Price  ...  Seller_Type_Individual  Transmission_Manual
# 0           3.35           5.59  ...                       0                    1
# 1           4.75           9.54  ...                       0                    1
# 2           7.25           9.85  ...                       0                    1
# 3           2.85           4.15  ...                       0                    1
# 4           4.60           6.87  ...                       0                    1
#
# [5 rows x 9 columns]

# %% [markdown]
# #**Correlation**

# %%
msg.corr()
# Out:
#                         Selling_Price  ...  Transmission_Manual
# Selling_Price                1.000000  ...            -0.367128
# Present_Price                0.878983  ...            -0.348715
# Kms_Driven                   0.029187  ...            -0.162510
# Owner                       -0.088344  ...            -0.050316
# Total_Year                  -0.236141  ...            -0.000394
# Fuel_Type_Diesel             0.552339  ...            -0.098643
# Fuel_Type_Petrol            -0.540571  ...             0.091013
# Seller_Type_Individual      -0.550724  ...             0.063240
# Transmission_Manual         -0.367128  ...             1.000000
#
# [9 rows x 9 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(msg)

# %% [markdown]
# **Pictorial representation with matplotlib**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corrmate=msg.corr()
top_cor_feature=corrmate.index
plt.figure(figsize=(20,20))

#Plot HeatMap

c=sns.heatmap(msg[top_cor_feature].corr(),annot=True,cMap="RdYlGn")
